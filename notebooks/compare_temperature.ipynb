# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
from matplotlib.dates import DateFormatter

# %%
data = pd.read_csv('../Data/10377.csv')

# %%
reanalysis = data['Reanalysis']
measured = data['Measured']

# %%
# with plt.xkcd():
dates = pd.date_range(date(2010,1,1),date(2011,1,1),freq='h')
fig, ax = plt.subplots(1,1, figsize = (12,6))
ax.plot(dates[:-1], measured, label = 'Misurati')
ax.plot(dates[:-1], reanalysis, label ='Reanalisi')
ax.set_ylim(-5,40)
ax.set_ylabel('Temperatura Lecco v. Sora [°C]')
ax.legend()
plt.show()

# %%
with plt.xkcd():
    plt.plot(measured-data_reanalysis[:8737], label = 'Difference')
    plt.ylim(-10,+10)
    plt.legend()
    plt.show()

print(np.median(abs(measured-data_reanalysis[:8737])))
# Out:
# 1.3684999999999494
